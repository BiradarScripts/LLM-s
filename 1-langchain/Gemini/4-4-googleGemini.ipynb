# %%
import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")

# %%
os.environ['GOOGLE_API_KEY']
# Out:
# 'AIzaSyD5LMe_lV7slnDKzHmICP62ColW3d0H2Js'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that gives the steps to be followed in a list format(high level not including planning and all) to build a website.",
    ),
    ("human", "Question:{question}")
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content="I understand you're looking for a structured approach to building a gym website using the MERN stack. Here's a breakdown of the steps involved, along with code examples where appropriate.\n\n## Building a Gym Website with MERN: Step-by-Step Guide\n\n**Frontend (React)**\n\n1. **Project Setup**\n\n   ```bash\n   terminal\n   npx create-react-app gym-app\n   cd gym-app\n   ```\n\n2. **Install Dependencies**\n\n   ```bash\n   terminal\n   npm install react-router-dom axios styled-components \n   ```\n\n3. **Component Structure (src/components)**\n\n   -   `Navbar.js`\n   -   `Hero.js`\n   -   `Classes.js`\n   -   `Schedule.js`\n   -   `Trainers.js`\n   -   `Pricing.js`\n   -   `Contact.js`\n   -   `Footer.js`\n\n4. **UI Implementation (src/components)**\n\n   ```javascript\n   code\n   // src/components/Navbar.js\n   import React from 'react';\n   import styled from 'styled-components';\n   import { Link } from 'react-router-dom';\n\n   const Nav = styled.nav`\n     b
# ...

# %%
print(ai_msg.content)
# Out:
# I understand you're looking for a structured approach to building a gym website using the MERN stack. Here's a breakdown of the steps involved, along with code examples where appropriate.
#
# ## Building a Gym Website with MERN: Step-by-Step Guide
#
# **Frontend (React)**
#
# 1. **Project Setup**
#
#    ```bash
#    terminal
#    npx create-react-app gym-app
#    cd gym-app
#    ```
#
# 2. **Install Dependencies**
#
#    ```bash
#    terminal
#    npm install react-router-dom axios styled-components
#    ```
#
# 3. **Component Structure (src/components)**
#
#    -   `Navbar.js`
#    -   `Hero.js`
#    -   `Classes.js`
#    -   `Schedule.js`
#    -   `Trainers.js`
#    -   `Pricing.js`
#    -   `Contact.js`
#    -   `Footer.js`
#
# 4. **UI Implementation (src/components)**
#
#    ```javascript
#    code
#    // src/components/Navbar.js
#    import React from 'react';
#    import styled from 'styled-components';
#    import { Link } from 'react-router-dom';
#
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant that translates {input_language} to {output_language}.",
        ),
        ("human", "{input}"),
    ]
)

chain = prompt | llm
result=chain.invoke(
    {
        "input_language": "English",
        "output_language": "German",
        "input": "I love programming.",
    }
)

# %%
## streamlit framework
import streamlit as st
st.title("Langchain Demo With Gemma Model")
input_text = st.text_input("What question you have in mind?")
# Out:
# 2024-09-20 09:04:14.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:04:14.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:04:14.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:04:14.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:04:14.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:04:14.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:04:14.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if input_text:
    try:
        result = llm.invoke({"question": input_text})
        st.write(result)
    except ConnectionError:
        st.error("Failed to connect to the Ollama service. Please ensure the service is running.")
    except Exception as e:
        st.error(f"An error occurred: {e}")

# %%
import streamlit as st

# Set up the title for the Streamlit app
st.title("Langchain Demo With Gemma Model")

# Input text for the question
input_text = st.text_input("What question do you have in mind?")

# Only proceed if there's input
if input_text:
    try:
        # Set up the messages structure
        messages = [
            ("system", "You are a helpful assistant that gives the steps to be followed in a list format (high level not including planning and all) to build a website."),
            ("human", f"Question: {input_text}")
        ]

        # Invoke the language model with the input messages
        result = llm.invoke({"messages": messages})
        
        # Display the result
        st.write(result)

    except ConnectionError:
        st.error("Failed to connect to the service. Please ensure the service is running.")
    except Exception as e:
        st.error(f"An error occurred: {e}")
# Out:
# 2024-09-20 09:05:54.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:05:54.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:05:54.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:05:54.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:05:54.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:05:54.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-09-20 09:05:54.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
